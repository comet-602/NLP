# %%
# !pip install jieba
# Out:
# Requirement already satisfied: jieba in /opt/conda/lib/python3.8/site-packages (0.42.1)

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-3.8.3-cp38-cp38-manylinux1_x86_64.whl (24.2 MB)
#      |████████████████████████████████| 24.2 MB 414 kB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.11.3 in /opt/conda/lib/python3.8/site-packages (from gensim) (1.19.0)
# Requirement already satisfied: scipy>=0.18.1 in /opt/conda/lib/python3.8/site-packages (from gensim) (1.4.1)
# Requirement already satisfied: six>=1.5.0 in /opt/conda/lib/python3.8/site-packages (from gensim) (1.15.0)
# Collecting smart-open>=1.8.1
#   Downloading smart_open-2.1.0.tar.gz (116 kB)
#      |████████████████████████████████| 116 kB 349 kB/s eta 0:00:01
# Requirement already satisfied: requests in /opt/conda/lib/python3.8/site-packages (from smart-open>=1.8.1->gensim) (2.24.0)
# Collecting boto
#   Downloading boto-2.49.0-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 287 kB/s eta 0:00:01
# Collecting boto3
#   Downloading boto3-1.14.27-py2.py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 338 kB/s eta 0:00:01
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests->smart-open>=1.8.1->gensim) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests->smart-open>=1.8.1->gensim) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests->smart-open>=1.8.1->gensim) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading s3transfer-0.3.3-py2.py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 421 kB/s eta 0:00:011
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting botocore<1.18.0,>=1.17.27
#   Downloading botocore-1.17.27-py2.py3-none-any.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 385 kB/s eta 0:00:01
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.8/site-packages (from botocore<1.18.0,>=1.17.27->boto3->smart-open>=1.8.1->gensim) (2.8.1)
# Collecting docutils<0.16,>=0.10
#   Downloading docutils-0.15.2-py3-none-any.whl (547 kB)
#      |████████████████████████████████| 547 kB 362 kB/s eta 0:00:01
# Building wheels for collected packages: smart-open
#   Building wheel for smart-open (setup.py) ... done
#   Created wheel for smart-open: filename=smart_open-2.1.0-py3-none-any.whl size=110317 sha256=efd8fdc32b31082c6378fb959b1781ec1b6d218747d1518a7bcf55e722d21584
#   Stored in directory: /home/jovyan/.cache/pip/wheels/a8/39/18/46aeab9eaf5317ec7f21924f2d0b11a856ad28207e87060140
# Successfully built smart-open
# Installing collected packages: boto, jmespath, docutils, botocore, s3transfer, boto3, smart-open, gensim
# Successfully installed boto-2.49.0 boto3-1.14.27 botocore-1.17.27 docutils-0.15.2 gensim-3.8.3 jmespath-0.10.0 s3transfer-0.3.3 smart-open-2.1.0

# %%
# !mkdir jieba_data

# %%
# !wget https://github.com/fxsjy/jieba/raw/master/extra_dict/dict.txt.big -O jieba_data/dict.txt.big
# Out:
# --2020-07-24 08:39:29--  https://github.com/fxsjy/jieba/raw/master/extra_dict/dict.txt.big
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big [following]
# --2020-07-24 08:39:31--  https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8583143 (8.2M) [text/plain]
# Saving to: ‘jieba_data/dict.txt.big’
#
# jieba_data/dict.txt 100%[===================>]   8.18M   706KB/s    in 14s
#
# 2020-07-24 08:39:45 (619 KB/s) - ‘jieba_data/dict.txt.big’ saved [8583143/8583143]

# %% [markdown]
# ### 載入 jieba 函式庫

# %%
import jieba

# %% [markdown]
# ### 載入繁體中文詞庫

# %%
jieba.set_dictionary('jieba_data/dict.txt.big')

# %% [markdown]
# ### 開啟文字檔

# %%
# 開檔
fileAllLines = []
with open('Three Kingdoms.txt') as fileLine:
    for line in fileLine:
        #print(line)
        fileAllLines.append(line)

# %% [markdown]
# ### 進行斷字斷詞

# %%
# 斷詞
seg = []
for i in range(len(fileAllLines)):
    #cut_list = list( jieba.cut_for_search(fileAllLines[i]) )
    cut_list = list( jieba.cut(fileAllLines[i], cut_all = False) )
    seg.append([' '.join([ item for item in cut_list if len(item) > 1 ])])
# Out:
# Building prefix dict from /home/jovyan/work/jieba_data/dict.txt.big ...
# Dumping model to file cache /tmp/jieba.ud3c40470d3518910bfd0dc86d865fad4.cache
# Loading model cost 3.448 seconds.
# Prefix dict has been built successfully.

# %%
print(len(seg))
# Out:
# 6001

# %%
seg = [ s for s in seg if len(s) > 0]

# %% [markdown]
# ### 準備存檔，將斷好的字詞存下來。先刪除之前留下的紀錄檔案(segDone.txt)

# %%
# !rm segDone.txt

# %% [markdown]
# ### 斷詞結果存檔

# %%
# 斷詞結果存檔
segSaveFile = 'segDone.txt'
with open(segSaveFile, 'wb') as saveFile:
    for i in range(len(seg)):
        words = seg[i][0].encode('utf-8')
        words = words.strip()
        if len(words) > 0:
            #saveFile.write(seg[i][0].encode('utf-8'))
            saveFile.write(words)
            saveFile.write('\n'.encode())

# %%
# !head -10 segDone.txt
# Out:
# 三國演義 作者 羅貫中
# 簡介
# 三國演義 一本 長篇 歷史小說 可以 中國 古代 長篇 章回小說 開山 之作 四大名著 之一 作者 明朝 羅貫中 故事 黃巾起義 終於 西晉 統一 百年 萬事 七實 三虛 三國 小說 通篇 精巧 敘述 謀略 被譽 中國 謀略 全書
# 羅貫中 1330 1400 之間 名本 湖海 散人 明代 通俗小說 籍貫 一說 太原 山西 一說 錢塘 浙江 杭州 不可 確考 據傳說 羅貫中 充任 過元末 農民 起義軍 張士誠 幕客 三國 通俗 演義 他還 創作 隋唐 志傳 通俗小說 太祖 龍虎風雲 戲劇 另外 相當 一部分 認為 水滸傳 三十 所作
# 目錄
# 001 桃園 豪傑 結義 黃巾 英雄 立功 002 張翼德 鞭督郵 何國舅
# 003 議溫明 董卓 叱丁原 饋金珠 李肅 呂布 004 廢漢帝 踐位 董賊 孟德獻刀
# 005 矯詔 諸鎮應 曹公 破關 兵三英 戰呂布 006 焚金 董卓 行兇 玉璽 孫堅 背約
# 007 袁紹 河戰 公孫 孫堅 跨江擊 劉表 008 王司徒 巧使 連環計 太師 大鬧 鳳儀亭
# 009 除暴 呂布 司徒 長安 賈詡 010 王室 騰舉義 報父仇 曹操 興師

# %%
# !cat segDone.txt | wc -c
# Out:
# 1314940

# %% [markdown]
# ### 載入word2vec 函式庫
# ### 參考網頁：https://radimrehurek.com/gensim/models/word2vec.html

# %%
from gensim.models import word2vec

# %% [markdown]
# ### 一行一行的從檔案中取出句子：一行一個句子，句子中的字必須預先處理好並以空白隔開

# %%
sentences = word2vec.LineSentence("segDone.txt")

# %%
import time

# %% [markdown]
# ### 訓練模型
# #### size: 向量維度 = 300
# #### iter: 迭代次數 = 100
# #### sg: 0(CBOW), 1(Skip-gram)

# %%
start_time = time.time()
model = word2vec.Word2Vec(sentences, size=300, iter=100, sg=0, window=15, workers=3)
print("--- spend %s seconds ---" % (time.time() - start_time))
# Out:
# --- spend 44.45010685920715 seconds ---

# %%
model

# %% [markdown]
# ### 儲存訓練好的word2vec 模型

# %%
model.save("word2vec.model")

# %%
model.corpus_total_words
# Out:
# 175124

# %% [markdown]
# # 詞相似度

# %%
model.wv.most_similar('赤壁')
# Out:
# [('干戈', 0.4600568413734436),
#  ('赤壁鏖兵', 0.4547407627105713),
#  ('東風', 0.446260005235672),
#  ('有意', 0.4357137680053711),
#  ('吳有', 0.431721568107605),
#  ('割據', 0.43037647008895874),
#  ('我心', 0.4171063005924225),
#  ('帝王', 0.4004780948162079),
#  ('吊君', 0.3970857560634613),
#  ('拆視', 0.3949670195579529)]

# %%
model.wv.similar_by_word('赤壁')
# Out:
# [('干戈', 0.4600568413734436),
#  ('赤壁鏖兵', 0.4547407627105713),
#  ('東風', 0.446260005235672),
#  ('有意', 0.4357137680053711),
#  ('吳有', 0.431721568107605),
#  ('割據', 0.43037647008895874),
#  ('我心', 0.4171063005924225),
#  ('帝王', 0.4004780948162079),
#  ('吊君', 0.3970857560634613),
#  ('拆視', 0.3949670195579529)]

# %%
model.wv.similarity('曹操','呂布')
# Out:
# 0.036041148

# %%
model.wv.similar_by_word('曹操')
# Out:
# [('操聞', 0.341972291469574),
#  ('荀彧', 0.3304579257965088),
#  ('相持', 0.32724565267562866),
#  ('謀士', 0.29754379391670227),
#  ('許都', 0.2959619164466858),
#  ('操寨', 0.28017503023147583),
#  ('南征', 0.2782037854194641),
#  ('同往', 0.2778371572494507),
#  ('操見', 0.27163028717041016),
#  ('許昌', 0.2701048254966736)]

# %%
model.wv.similar_by_word('呂布')
# Out:
# [('侯成', 0.5251067876815796),
#  ('宋憲', 0.519384503364563),
#  ('魏續', 0.49688032269477844),
#  ('高順', 0.4924231171607971),
#  ('濮陽', 0.43562832474708557),
#  ('田氏', 0.434565007686615),
#  ('曹性', 0.4228643774986267),
#  ('呂布乃', 0.41999781131744385),
#  ('布乃', 0.41784876585006714),
#  ('呂布見', 0.4117080569267273)]

# %%
model.wv.similarity('孔明','諸葛亮')
# Out:
# 0.1449911

# %%
model.wv.similar_by_word('孔明')
# Out:
# [('孔明自', 0.4405563473701477),
#  ('孔明之', 0.39085114002227783),
#  ('三洞', 0.3853200376033783),
#  ('金環三結', 0.36729922890663147),
#  ('羽扇', 0.367171049118042),
#  ('孔明遂', 0.35829177498817444),
#  ('孔明問', 0.3478687107563019),
#  ('元帥', 0.34098318219184875),
#  ('孔明笑', 0.33544787764549255),
#  ('魏延之', 0.33294469118118286)]

# %%
model.wv.similar_by_word('諸葛亮')
# Out:
# [('子丹', 0.3725571036338806),
#  ('深通', 0.3642802834510803),
#  ('仇敵', 0.36159205436706543),
#  ('之計', 0.3607364892959595),
#  ('兵符', 0.35628819465637207),
#  ('武鄉侯', 0.3548797369003296),
#  ('將者', 0.34660494327545166),
#  ('奏聞', 0.34293341636657715),
#  ('成大功', 0.3413265645503998),
#  ('決勝負', 0.33821386098861694)]

# %%
model.wv.similarity('孔明','周瑜')
# Out:
# 0.08815672

# %%
model.wv.similarity('孔明','司馬懿')
# Out:
# 0.25500503

# %%
input_string = input('關鍵字:')
model.wv.similar_by_word(input_string)
# Out:
# 關鍵字:放火
# [('為號', 0.5816054344177246),
#  ('引火', 0.5480406284332275),
#  ('軍入', 0.5466700196266174),
#  ('乾柴', 0.5408149361610413),
#  ('裡應', 0.5117939710617065),
#  ('城內', 0.5061523914337158),
#  ('吶喊', 0.5031964778900146),
#  ('只留', 0.49323415756225586),
#  ('外合', 0.4803662896156311),
#  ('縱火', 0.4741276204586029)]

# %% [markdown]
# # 詞預測

# %%
result = model.predict_output_word('關羽')
print(result)
# Out:
# None
# /opt/conda/lib/python3.8/site-packages/gensim/models/word2vec.py:969: UserWarning: All the input context words are out-of-vocabulary for the current model.
#   warnings.warn("All the input context words are out-of-vocabulary for the current model.")

# %% [markdown]
# # 類推 (analogy)

# %% [markdown]
# #### 基本範例 (https://radimrehurek.com/gensim/models/keyedvectors.html)

# %%
import gensim.downloader as api

# %%
word_vectors = api.load("glove-wiki-gigaword-100")  # load pre-trained word-vectors from gensim-data
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %%
result = word_vectors.most_similar(positive=['woman', 'king'], negative=['man'])
print("{}: {:.4f}".format(*result[0]))
# Out:
# queen: 0.7699

# %%
result = word_vectors.most_similar_cosmul(positive=['woman', 'king'], negative=['man'])
print("{}: {:.4f}".format(*result[0]))
# Out:
# queen: 0.8965

# %%
ans1 = model.wv.most_similar(positive=['劉備','孔明'], negative=['孫權'])
print("%s: %s"%(ans1[0]))
# Out:
# 王忠: 0.2855539917945862

# %%
from sklearn.decomposition import IncrementalPCA    # inital reduction
from sklearn.manifold import TSNE                   # final reduction
import numpy as np                                  # array handling

# %%
def reduce_dimensions(model):
    num_dimensions = 2  # final num dimensions (2D, 3D, etc)

    vectors = [] # positions in vector space
    labels = [] # keep track of words to label our data again later
